# %%
import pandas as pd
import yfinance as yf

# %%
df = pd.read_excel("børsnoterede_virk.xlsx")

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#                   Navn  Symbol          ISIN  ICB Code
# 1               Ørsted  ORSTED  DK0060094928    6510.0
# 2                Össur    OSSR  IS0000000040    2010.0
# 3       Zealand Pharma    ZEAL  DK0060257814    2010.0
# 4  Victoria Properties   VIPRO  DK0015216675    3510.0
# 5        Vestjysk Bank    VJBA  DK0010304500    3010.0

# %%
tickers = []
for i in df.Symbol:
    ticker = i+".CO"
    tickers.append(ticker)

# %%
data = yf.download(tickers=tickers,\
                  period ="max",\
                  interval = "1d",\
                  group_by = 'ticker',\
                  auto_adjust = True
                  )
# Out:
# [*********************100%***********************]  131 of 131 completed
#
# 1 Failed download:
# - BOOZT-DKK.CO: 1d data not available for startTime=-2208988800 and endTime=1615131312. Only 100 years worth of day granularity data are allowed to be fetched per request.

# %%
price_df = pd.DataFrame()
for i in tickers:
    price_df = pd.concat([price_df,data[str(i)].Close],axis=1)

# %%
price_df.columns = tickers

# %%
price_df
# Out:
#              ORSTED.CO    OSSR.CO     ZEAL.CO    VIPRO.CO  VJBA.CO  VWS.CO  \
# 2000-01-03         NaN        NaN         NaN         NaN      NaN     NaN
# 2000-01-04         NaN        NaN         NaN         NaN      NaN     NaN
# 2000-01-05         NaN        NaN         NaN         NaN      NaN     NaN
# 2000-01-06         NaN        NaN         NaN         NaN      NaN     NaN
# 2000-01-07         NaN        NaN         NaN  147.196381      NaN     NaN
# ...                ...        ...         ...         ...      ...     ...
# 2021-03-01  989.500000  43.500000  202.800003    0.980000    2.825  1173.5
# 2021-03-02  967.799988  43.200001  205.800003    0.970000    2.825  1149.0
# 2021-03-03  920.400024  43.549999  196.500000    0.960000    2.905  1090.0
# 2021-03-04  920.000000  43.750000  196.300003    0.910000    2.860  1085.0
# 2021-03-05  900.000000  43.200001  191.100006    0.930000    2.860  1042.5
#
#                  UIE.CO     TRYG.CO    TOTA.CO  TRMD-A.CO  ...       BO.CO  \
# 2000-01-03    49.438213         NaN        NaN        NaN  ...  120.864929
# 2000-01-04    49.438213         NaN        NaN        NaN  ...  112.747131
# 2000-01-05    49.438213         NaN        NaN        NaN  ...  110.041214
# 2000-01-06    49.438213         NaN        NaN        NaN  ...  109.590218
# 2000-01-07    49.438213         NaN        NaN        NaN  ...  112.747131
# ...                 ...         ...        ...        ...  ...         ...
# 2021-03-01  1585.000000  184.300003  93.199997  49.450001  ...   33.099998
# 2021-03-02  1600.000000  186.500000  92.000000  53.200001  ...   33.119999
# 2021-03-03  1615.000000  178.500000  94.000000  52.599998  ...   31.540001
# 2021-03-04  1615.000000  136.199997  92.199997  51.299999  ...   30.639999
# 2021-03-05  1645.000000  136.000000  92.199997  50.299999  ...   29.820000
#
#             ATLA-DKK.CO   AMBU-B.CO    ALMB.CO  ALK-B.CO  AGF-B.CO    AGAT.CO  \
# 2000-01-03          NaN         NaN  26.348440       NaN       NaN  73.921181
# 2000-01-04          NaN         NaN  25.860504       NaN       NaN  73.396927
# 2000-01-05          NaN         NaN  25.128603       NaN       NaN  70.775604
# 2000-01-06          NaN         NaN  25.616539       NaN       NaN  73.396927
# 2000-01-07          NaN         NaN  26.104473       NaN       NaN  73.396927
# ...                 ...         ...        ...       ...       ...        ...
# 2021-03-01         5.66  287.100006  70.500000    2658.0     0.770   1.860000
# 2021-03-02         5.62  282.799988  70.800003    2602.0     0.754   1.865000
# 2021-03-03         5.50  266.600006  69.300003    2548.0     0.766   1.860000
# 2021-03-04         5.56  260.899994  68.199997    2406.0     0.764   1.880000
# 2021-03-05         5.56  255.899994  67.900002    2368.0     0.766   1.860000
#
#                  AAB.CO   MAERSK-B.CO  MAERSK-A.CO
# 2000-01-03  6215.422363   4590.501953     4026.125
# 2000-01-04  6243.108887   4426.554688     4026.125
# 2000-01-05  6243.108887   4280.825195     4026.125
# 2000-01-06  6134.533203   4317.256836     4026.125
# 2000-01-07  6704.556152   4335.473633     4026.125
# ...                 ...           ...          ...
# 2021-03-01    42.000000  13780.000000    12730.000
# 2021-03-02    42.400002  13730.000000    12750.000
# 2021-03-03    42.400002  13600.000000    12650.000
# 2021-03-04    42.400002  13405.000000    12550.000
# 2021-03-05    41.400002  13450.000000    12540.000
#
# [5363 rows x 131 columns]

# %%
komp_df = pd.read_csv("UDFYLD.csv",sep="\t")
# Out:
# /Users/smeden/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (8) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
komp_df.head()
# Out:
#    Unnamed: 0                    ID language  \
# 0           0  k20190101h8526003340       da
# 1           1  k20190101h8526003340       da
# 2           2  k20190101h8526003340       da
# 3           3  k20190101h8526003340       da
# 4           4  k20190101h8526003340       da
#
#                                    line1        dato     aar  maaned  \
# 0  Kunderådgiver til filialen i Brønshøj  20190101.0  2019.0     1.0
# 1  Kunderådgiver til filialen i Brønshøj  20190101.0  2019.0     1.0
# 2  Kunderådgiver til filialen i Brønshøj  20190101.0  2019.0     1.0
# 3  Kunderådgiver til filialen i Brønshøj  20190101.0  2019.0     1.0
# 4  Kunderådgiver til filialen i Brønshøj  20190101.0  2019.0     1.0
#
#                    firma match_cvr  prob_cvr  \
# 0  Arbejdernes Landsbank  31467012       1.0
# 1  Arbejdernes Landsbank  31467012       1.0
# 2  Arbejdernes Landsbank  31467012       1.0
# 3  Arbejdernes Landsbank  31467012       1.0
# 4  Arbejdernes Landsbank  31467012       1.0
#
#                      match_cvr_virknavn  match_cvr_branche  \
# 0  AKTIESELSKABET ARBEJDERNES LANDSBANK           641900.0
# 1  AKTIESELSKABET ARBEJDERNES LANDSBANK           641900.0
# 2  AKTIESELSKABET ARBEJDERNES LANDSBANK           641900.0
# 3  AKTIESELSKABET ARBEJDERNES LANDSBANK           641900.0
# 4  AKTIESELSKABET ARBEJDERNES LANDSBANK           641900.0
#
#   match_cvr_ansatte_str                                               Komp  \
# 0     ANTAL_1000_999999   rådgive og sparre med eksisterende og nye kunder
# 1     ANTAL_1000_999999  være med til at markedsføre filialen i lokalom...
# 2     ANTAL_1000_999999  god til at skabe relationer som spændende med ...
# 3     ANTAL_1000_999999                                          udadvendt
# 4     ANTAL_1000_999999                                          udadvendt
#
#   KompKode                                   KompNiveau1  \
# 0    S1.06  Kommunikere, samarbejde og udøve kreativitet
# 1    S1.06  Kommunikere, samarbejde og udøve kreativitet
# 2    S1.06  Kommunikere, samarbejde og udøve kreativitet
# 3    A2.02                         Værdier og holdninger
# 4    A2.02                         Værdier og holdninger
#
#                   KompNiveau2 digitale_ord digitalt_flag
# 0  Markedsføre, sælge og købe           []    alle andre
# 1  Markedsføre, sælge og købe           []    alle andre
# 2  Markedsføre, sælge og købe           []    alle andre
# 3           Have gode manerer           []    alle andre
# 4           Have gode manerer           []    alle andre
